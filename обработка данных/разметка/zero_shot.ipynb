# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from IPython.display import clear_output

# %%
# !pip install gdown
# !pip install transformers
# !pip install sentencepiece
clear_output()

# %%
# !gdown https://drive.google.com/uc?id=1M4KnsDq_xeqACZQi30NLT1CYzqHl6b21
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M4KnsDq_xeqACZQi30NLT1CYzqHl6b21
# To: /content/streets_cheb.csv
# 100% 27.2k/27.2k [00:00<00:00, 12.6MB/s]

# %%
# !wget https://clck.ru/YT75w -O data.zip
# !unzip -u data.zip
# Out:
# --2021-10-30 07:54:09--  https://clck.ru/YT75w
# Resolving clck.ru (clck.ru)... 213.180.204.221, 2a02:6b8::221
# Connecting to clck.ru (clck.ru)|213.180.204.221|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://sba.yandex.net/redirect?url=https%3A%2F%2Fstorage.yandexcloud.net%2Fhackai-datasetrsv%2FArchive.zip&client=clck&sign=b351c9bcc3485cf0572cef79be48d6df [following]
# --2021-10-30 07:54:09--  https://sba.yandex.net/redirect?url=https%3A%2F%2Fstorage.yandexcloud.net%2Fhackai-datasetrsv%2FArchive.zip&client=clck&sign=b351c9bcc3485cf0572cef79be48d6df
# Resolving sba.yandex.net (sba.yandex.net)... 87.250.251.232, 87.250.250.232, 77.88.21.232, ...
# Connecting to sba.yandex.net (sba.yandex.net)|87.250.251.232|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://storage.yandexcloud.net/hackai-datasetrsv/Archive.zip [following]
# --2021-10-30 07:54:10--  https://storage.yandexcloud.net/hackai-datasetrsv/Archive.zip
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1225404 (1.2M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   1.17M  1.38MB/s    in 0.8s
#
# 2021-10-30 07:54:12 (1.38 MB/s) - ‘data.zip’ saved [1225404/1225404]
#
# Archive:  data.zip

# %%
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from nltk.stem.snowball import SnowballStemmer
from tqdm import tqdm
from functools import lru_cache
from nltk.tokenize import word_tokenize
import nltk
import gc
from humanize import naturalsize
from copy import deepcopy
nltk.download('punkt')

stemmer = SnowballStemmer("russian")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
@lru_cache(maxsize=None)
def stem(text):
    return stemmer.stem(text)

# %%
model_checkpoint = 'cointegrated/rubert-base-cased-nli-twoway'
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(model_checkpoint)
if torch.cuda.is_available():
    model.cuda()

# %%
df = pd.read_csv("/content/streets_cheb.csv")

# %%
df["object_group"].unique()
# Out:
# array(['Улицы Чебоксар', 'Проспекты Чебоксар', 'Переулки Чебоксар',
#        'Проезды Чебоксар', 'Бульвары Чебоксар', 'Шоссе Чебоксар'],
#       dtype=object)

# %%
df["object_group"] = df["object_group"].str.replace(" Чебоксар", "").str.strip()

# %%
encode = {"Улицы": "Улица",
          "Проспекты": "Проспект",
          "Переулки": "Переулок",
          "Проезды": "Проезд",
          "Бульвары": "Бульвар",
          "Шоссе": "Шоссе"}

# %%
df["object_group"] = df["object_group"].apply(lambda x: encode[x])

# %%
df["address"] = df["object_group"] + " " + df["item_name"]

# %%
classes = df["address"].to_list()
n_classes = len(classes)

# %%
def predict_zero_shot(text, label_texts, model, tokenizer,
                      label='entailment', normalize=True):
    text = " ".join([stem(i) for i in word_tokenize(text)])
    tokens = tokenizer([text] * n_classes, label_texts,
                       truncation=True, return_tensors='pt',
                       padding=True, max_length=150)
    del text
    with torch.inference_mode():
        result = torch.softmax(model(**tokens.to(model.device)).logits, -1)
    proba = result[:, model.config.label2id[label]].cpu().numpy()
    if normalize:
        proba /= sum(proba)
    del result
    gc.collect()
    torch.cuda.empty_cache()
    gc.collect()
    return label_texts[proba.argmax()]

# %%
predict_zero_shot('город Чебоксары улица К.Либкнехта дом 13', classes, model, tokenizer)
# Out:
# 'Улица К.Либкнехта'

# %%
df2 = pd.read_excel("/content/обращения граждан на портале народный контроль.xlsx").dropna(subset=["Текст обращения"])

# %%
arr = []
for i in tqdm(df2["Текст обращения"]):
    arr.append(predict_zero_shot(i, classes, model, tokenizer))
    gc.collect()
    t = torch.cuda.get_device_properties(0).total_memory
    r = torch.cuda.memory_reserved(0)
    a = torch.cuda.memory_allocated(0)
    f = r-a # free inside reserved
    print(naturalsize(f))
    clear_output()
# Out:
# 100%|██████████| 3137/3137 [1:32:26<00:00,  1.77s/it]

# %%
df2["street"] = arr

# %%
df2.to_csv("обращения_граждан_add_street.csv", index=False)

# %%
for i in df2[["Текст обращения", "street"]].values[:10]:
    print(i)
    print("------------")
# Out:
# ['Летом во дворе дома Филиппа Лукина 6 проводились работы по замене асфальтного покрытия, на время работ урны убрали. Почему до сих пор их не монтируют обратно?\nСоздание ссылки'
#  'Улица Патриса Лумумбы']
# ------------
# ['После выборов в лесу за Кадетском сквером лежат агитационные листовки относительно Салаевой А. Л. Весь лес усыпан ими, как грибы. '
#  'Улица Юннатская']
# ------------
# ['Опасный перекрёсток Академика Крылова / Пирогова. Светофоры несколько лет не работают, только установлены знаки пешеходный переход, в настоящее время из-за ремонта дороги даже нет разметки. Для пешеходов опасно переходить дорогу особенно когда темно, поскольку из-за активного нерегулиремого движения внимание расфокусируется. Ни один раз наблюдала, в том числе, когда сама переходила дорогу, как людям, в том числе с маленькими детьми, приходится махать руками вовремя перехода улицы, чтобы избежать дтп! Страшно. \nДля водителей- чтобы выехать на 30-ю дорогу с домов академика Крылова, приходится разворачиваться на Радужном, а чтобы попасть домой- развернуться там же, приехать вниз на кольцо и снова подниматься наверх. При этом не все соблюдают правила, возникает опасность для всех участников дорожного движения. Маршрут распространённый, в окрестностях много жилых домов, бассейн ЧГПУ, детский сад, больница. Считаю, важно, чтобы люди чувствовали безопасность  при переходе улицы в предназначенных местах! '
#  'Улица П.Н.Осипова']
# ------------
# ['Долгое время в жилой зоне, а именно на ул. Маркова 16/15, возле здания Пятёрочки(сверху парковка) стоит сломанный заброшенный автомобиль в ужасном состоянии. Видно, что поджигался. Иногда в нем сидят сомнительные люди. Особенно жутко проходить мимо в темное время суток. Также очень портит облик района. Рядом жилые дома и детская площадка, напротив через залив дом Правительства. Также дополнительно могу предоставить видео. Пожалуйста, примите меры!'
#  'Улица Достоевского']
# ------------
# ['Водитель маршрута не остановил на остановке Чиршкасы на трассе, был случай, не остановил на остановке Чиганары, когда нужно было добраться в Чиршкасы. Это маршрут только для выезжающих из Чебоксары и Януша? Тогда на чем должны добираться жители Чиганары, которые отводят детей в до школьную группу в Чиршкасы, выезжают из д. Чиршкасы трассы в другие населённые пункты района? '
#  'Проезд Дорожный']
# ------------
# ['Здравствуйте, в этом году по улице 50 Лет Октября вдоль всей улицы установили фонари уличного освещения: светодиодные, яркие всё по высшему разряду, ОГРОМНОЕ спасибо Администрации города! Дело в том, что по улице 50 Лет Октября нет ни одной скамейки, раньше скамейки были возле Развлекательного Центра МегаГелакси, но после того как администрация данного заведения видела что там собираются много мам с колясками решила "прикрыть лавочки", оградили все забором, сняли скамейки и вывесили объявление что это частная территория и нечего сюда соваться - тут везде камеры! Прошу установить скамейки вдоль улицы 50 Лет Октября, спасибо'
#  'Улица 50 лет Октября']
# ------------
# ['Здравствуйте,  на тротуаре перед входом в детский садик №73 (Полянка), по адресу Космонавта Николаева 35 а (вход со стороны дома Космонавта Николаева 39), бывает много грязи, потому что некоторые индивидуумы умудряются разворачиваться на автомобилях. Прошу установить высокие бордюры, разделяющие грязь и асфальт, чтобы не хватало наглости тут разворачиваться'
#  'Улица Космонавта Николаева А.Г.']
# ------------
# ['открытая яма в Парке победы рядом  с часовней . сняли крышку слива .'
#  'Проезд Соляное']
# ------------
# ['Тратуар весь в грязи.Пройти невозможно, тем более с коляской.'
#  'Улица Марата']
# ------------
# ['Ул.афанасьева д.13 возле 1 подъезда произошёл провал асфальта после земляных работ.так же оба заезда к дому все в ямах и выбоинах.примите меры к исправлению ситуации.'
#  'Улица Афанасьева']
# ------------

# %%
ord("а"), ord("я")
# Out:
# (1072, 1103)

# %%
"".join([chr(i) for i in range(1072, 1104)])
# Out:
# 'абвгдежзийклмнопрстуфхцчшщъыьэюя'

# %%
def is_have_digit(text):
    for i in text:
        if i.isdigit():
            return True
    return False

def is_correct(text):
    for i in text:
        if i not in "./,1234567890ёабвгдежзийклмнопрстуфхцчшщъыьэюя":
            return False
    return True

with_houses = []
houses = []
for idx, i in enumerate(df2[["Текст обращения", "street"]].values):
    text = i[0].lower()
    street = i[1].split()[-1].lower()
    t = text.find(street)
    if t != -1:
        temp = text[t:t + 100].split()[:2]
        try:
            if is_correct(temp[1]) and is_have_digit(temp[1]):
                with_houses.append(idx)
                houses.append(i[1] + " " + temp[1])
        except: pass

# %%
new_df = deepcopy(df2.iloc[with_houses].copy())

# %%
new_df["street"] = houses

# %%
new_df.to_csv("обращения_граждан_full_address.csv", index=False)
